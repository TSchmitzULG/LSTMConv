# %% [markdown]
# # Learn simple layer of LSTM

# %% [markdown]
# add conv layer
# add l2 regularizer
# add LSTMBlockFused
# remove dropout to add optimized graph, add quantized graph

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import os
import sys
sys.path.append('Codes')
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pickle
from dataShaping import *
from savePerf import *
from saveTransformedGraph import optimizeGraph
import scipy.io.wavfile
import time
from tensorflow.contrib.layers import fully_connected
from tensorflow.contrib.rnn import *




modelName = "LSTM28"
# create directory experiment
date = time.strftime("%Y-%m-%d-%H-%M")
path = os.path.join("Experiments",date)
if not os.path.isdir(path):
    os.makedirs(path)
    #experiment/"date"/temp will contain the backuped model parameters
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
    # if you run the file two time in a minute
else :
    date = date+'(2)'
    path = os.path.join("Experiments",date)
    os.makedirs(path)
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)

# directory that will contain tensorboard information
pathLog = 'Tf_logs'
if not os.path.isdir(pathLog):
    os.makedirs(pathLog)
pathLog = "{}/run-{}/".format(pathLog,date)

version = tf.__version__
print ("version {} of tensorflow".format(version))

#############################
# Model parameters
#############################
trainTestRatio = 0.9
#if you cannot load all the data set in Ram specify wich part you want to load (0 means all the dataset)
maxSize = int(np.floor(44100*11.4))
num_step = 180                                       # time step before reduction
#num_LSTM = 10                                         # num LSTM (time step after reduction)
conv_chan = 35                                         #number of kernel for convolution
conv_strides = 3#int(np.ceil(num_step/num_LSTM))                  #decay between two convolution
conv_size = 12                                         #filter size for the convolution
#size_poll = 4
reg_scale = 0.0
l1l2Prop = 0.4  # 1 =>l1, 0=> l2
reg_scale_l1 = l1l2Prop*reg_scale
reg_scale_l2 = ((1-l1l2Prop)/2)*reg_scale
num_hidden = 150                                      #num of hidden units
num_class = 1                                          #size of the output
num_feature = 1                                        # size of the input
batch_size = 2500                                   # number of sequence taken before to compute the gradient
n_layer = 1                                             #num_layer

#num_hidden = num_hidden/keep_prob
num_epoch = 100000                                      # process all the datas num_epoch times
trainDuration = 60*60*1                             # or during a determined duration(second)
fileName = 'Datasets/trainingENGL5.mat'             #dataset train/test path
fileNameValidation = 'Datasets/validationENGL5.mat' # dataset validation path


#############################
# Loading data
#############################
matrix = sio.loadmat(fileName)
matrix = matrix['training']
if maxSize ==0:
    maxSize = len(matrix)
    print(maxSize)
# to do shuffle matrix by num_step length
train_input,train_output,test_input,test_output = splitShuffleData(matrix,num_step,trainTestRatio,maxSize)
print("shape input train {}".format(np.shape(train_input)))
numTrain = len(train_output)
print ("Data loaded")
#######################
#Graph
#######################

G = tf.Graph()
with G.as_default():
    with tf.name_scope("placeHolder"):
        data = tf.placeholder(tf.float32, [None, num_step], name ="data") #Number of examples, number of input step (time step), dimension of each input
        target = tf.placeholder(tf.float32, [None, num_class],name = "target") # batchSize, nbClass

    dataShaped = tf.reshape(data,[tf.shape(data)[0],num_step,1,1]) # batchSize, num_step num_feature
    with tf.name_scope("ConvLayers"):
        regularizerC1 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC1")
        dataReduced = tf.layers.conv2d(inputs = dataShaped,filters = conv_chan,
                                       kernel_size = (conv_size,1),strides=(4,1),
                                       padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC1,name="C1")#batch_size num_Lstm num_channel
        regularizerC2 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC2")
        dataReduced = tf.layers.conv2d(inputs = dataReduced,filters = conv_chan,
                                       kernel_size = (conv_size,1),strides=(3,1),
                                       padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC2,name="C2")#batch_size num_Lstm num_channel
        #regularizerC3 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regC3")
        #dataReduced = tf.layers.conv2d(inputs = dataReduced,filters = conv_chan,
        #                               kernel_size = (conv_size,1),strides=(2,1),
        #                               padding = "same",activation=tf.nn.elu,kernel_regularizer=regularizerC3,name="C3")#batch_size num_Lstm num_channel
    dataReduced = tf.reshape(dataReduced,[tf.shape(data)[0],tf.shape(dataReduced)[1],conv_chan])
    
    fusedCell = tf.contrib.rnn.LSTMBlockFusedCell(num_hidden,use_peephole=False)

    dataReduced = tf.transpose(dataReduced,[1,0,2])

    with tf.name_scope("extractLastValueLSTM"):
        val, state = fusedCell(dataReduced,initial_state=None,dtype=tf.float32) # val dim is [batchSize,num_step, numhidden]
        last_index = tf.shape(val)[0] - 1
        last = tf.gather(val,last_index)

    #Send the output of the lsat LSTM cell into a Fully connected layer to compute the prediciton pred[n] 
    
    with tf.variable_scope("FCLayer"):
        regularizerFC1 = tf.contrib.layers.l1_l2_regularizer(scale_l1=reg_scale_l1,scale_l2=reg_scale_l2,scope="regFC1")
        weight = tf.get_variable("weight", shape=[num_hidden, int(target.get_shape()[1])],regularizer=regularizerFC1, initializer=tf.contrib.layers.xavier_initializer())
        bias = tf.Variable(tf.constant(0., shape=[target.get_shape()[1]]))
        prediction = tf.nn.tanh((tf.add(tf.matmul(last, weight) , bias)),name = "prediction") #[batchSize,nclass]
    
    #Compute the mean square error
    MSE = tf.reduce_mean(tf.square(prediction-target))
    
    #get regularizer
    reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    MSEReg = tf.add_n([MSE]+reg_losses,name="MSEReg")
    # create optimizer
    optimizer = tf.train.AdamOptimizer()
    #Compute gradient and apply backpropagation
    minimize = optimizer.minimize(MSEReg)

    # Create summary view for tensorboard
    mse_summary = tf.summary.scalar('RMSE',tf.sqrt(MSE))
    summary_op = tf.summary.merge_all()
    
    #Create an init op to initialize variable
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver() # save variable, use saver.restore(sess,"date/tmp/my_model.ckpt") instead of sess.run(init_op)

##############################
# Execution du graphe
##############################
    
with tf.Session(graph=G) as sess:
    #restorePath = os.path.join('2017-09-11-18-07','temp','my_model.ckpt') # example for restore a previous model
    #saver.restore(sess,restorePath)
    sess.run(init_op)
    train_writer = tf.summary.FileWriter(pathLog+'train',graph =tf.get_default_graph())
    test_writer = tf.summary.FileWriter(pathLog+'test')

    no_of_batches = int(np.floor((numTrain)/batch_size)) # numtrain -numstep ?
    no_of_batchesTest = int(np.floor((len(test_input))/batch_size))
    tStart = time.clock()
    epoch =0
    for epoch in range(num_epoch):
        tEpoch = time.clock()
        if (time.clock()-tStart < trainDuration):
            ptr = 0
            if epoch % 20==0 : # each ten epoch save the model
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myGraph.pb',as_text=False)
                save_path = saver.save(sess,os.path.join(pathTemp,'myModel.ckpt'))
            pMSETrain=0
            for j in range(no_of_batches):
                inp, out = train_input[ptr:ptr+batch_size],train_output[ptr:ptr+batch_size]
                ptr+=batch_size
                if j % np.floor(trainTestRatio*10) ==0 : # This is to have a train summary and a test summary of the same size
                    _,summary_str,pMSETrainTemp = sess.run([minimize,summary_op,MSE],{data: inp, target: out})

                    pMSETrain += pMSETrainTemp
                    step = epoch*no_of_batches+j
                    train_writer.add_summary(summary_str,step)
                else :
                    sess.run([minimize],{data: inp, target: out})
                   
            RMSETrain = np.sqrt(pMSETrain/no_of_batchesTest)
            print ("Epoch -{} calculated in {:5.2f} s ".format(epoch,time.clock()-tEpoch))
            # evaluate the model on the test set (compute the mean of the MSE)
            pMSE = 0
            ptr2 = 0
            for k in range(no_of_batchesTest):
                pMSETemp,summary_str = sess.run([MSE,summary_op],{data: test_input[ptr2:ptr2+batch_size] , target: test_output[ptr2:ptr2+batch_size]})
                pMSE += pMSETemp
                ptr2 += batch_size
                step = epoch*no_of_batchesTest+k
                test_writer.add_summary(summary_str,step*10*trainTestRatio)
                RMSETest=np.sqrt(pMSE/no_of_batchesTest)
            print("Epoch {} MSE {:.5} on test set with deviation of {:.2f}%".format(epoch,RMSETest,100*np.sqrt((RMSETrain-RMSETest)**2)/RMSETrain))
        else : break # break the while loop if number of epoch is reached
    tStop = time.clock()
    trainTime = time.strftime("%d:%H:%M:%S ", time.gmtime(tStop-tStart))
    
    #######################
    # Save Graph variable and information about the running session
    #######################
    # save graph model
    tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myFinalGraph.pbtxt',as_text=True)
    # Save checkpoint variables
    save_path = saver.save(sess,os.path.join(pathTemp,'myFinalModel.ckpt'))
    print ("Training duration {}".format(trainTime))
    totalParameters =np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()])
    print("Number of training variable {}".format(totalParameters))
    # log
    infoLog={}
    infoLog["path"] = path
    infoLog["MSE"] = np.sqrt(pMSE/no_of_batchesTest)
    infoLog["num_step"] = num_step
    infoLog["num_hidden"] = num_hidden
    infoLog["num_epoch"] = epoch
    infoLog["batch_size"] = batch_size
    infoLog["maxSize"] = maxSize
    infoLog["duration"] = trainTime
    infoLog["totalParameters"] = totalParameters
    infoLog["version"] = version
    infoLog["n_layer"] = n_layer
    infoLog["trainDropout"] = 0
    infoLog["nameModel"] = modelName
    infoLog["conv_chan"] = conv_chan
    infoLog["strides"] = conv_strides
    infoLog["conv_size"] = conv_size
    logPerf(infoLog)
    input_nodes=["placeHolder/data"]
    output_nodes=["FCLayer/prediction"]
    optimizeGraph(pathTemp,input_nodes,output_nodes)
    
    
                                                 
    
    ###############################
    #   validation dataset and emulate guitar signal
    ###############################
    matrixVal = sio.loadmat(fileNameValidation)
    matrixVal = matrixVal['validation']  
    # shape validation test
    val_input,val_output = shapeData(matrixVal,num_step,maxSize)
    lPrediction = []
    lTarget = []
    ptr3 = 0
    no_of_batchesVal = int(np.floor((len(val_input))/batch_size))
    for k in range(no_of_batchesVal):
        pPrediction,pTarget = sess.run([prediction,target],{data: val_input[ptr3:ptr3+batch_size], target: val_output[ptr3:ptr3+batch_size]}) 
        lPrediction.append(pPrediction)
        lTarget.append(pTarget)   
        ptr3+=batch_size
    #plt.show()scree
    predictionArray = np.array(lPrediction,dtype=np.float32).ravel()
    targetArray = np.array(lTarget,dtype=np.float32).ravel()
    scipy.io.wavfile.write(os.path.join(path,'prediction.wav'),44100,predictionArray)
    scipy.io.wavfile.write(os.path.join(path,'target.wav'),44100,targetArray)

    # save emulation in a pickle format
    ax = plt.subplot(111)
    ax.plot(predictionArray[:10000],label='prediction')
    ax.plot(targetArray[:10000],label='target')
    ax.legend()
    nameFigEstimation = os.path.join(path,"targetVsPrediction.pickle")
    pickle.dump(ax,open(nameFigEstimation, 'wb'))
print ("done, good job kids")
# Out:
# version 1.4.1 of tensorflow
# shape input train (452466, 180)
# Data loaded
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:96: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch -0 calculated in  4.32 s
# Epoch 0 MSE 0.17845 on test set with deviation of 2.2e+01%
# Epoch -1 calculated in  3.68 s
# Epoch 1 MSE 0.12662 on test set with deviation of 1.5e+01%
# Epoch -2 calculated in  3.63 s
# Epoch 2 MSE 0.11269 on test set with deviation of 5.4%
# Epoch -3 calculated in  3.65 s
# Epoch 3 MSE 0.10685 on test set with deviation of 2.6%
# Epoch -4 calculated in  3.66 s
# Epoch 4 MSE 0.1032 on test set with deviation of 1.8%
# Epoch -5 calculated in  3.64 s
# Epoch 5 MSE 0.10005 on test set with deviation of 1.6%
# Epoch -6 calculated in  3.65 s
# Epoch 6 MSE 0.097257 on test set with deviation of 1.5%
# Epoch -7 calculated in  3.74 s
# Epoch 7 MSE 0.094721 on test set with deviation of 1.4%
# Epoch -8 calculated in  3.83 s
# Epoch 8 MSE 0.092363 on test set with deviation of 1.2%
# Epoch -9 calculated in  3.72 s
# Epoch 9 MSE 0.090113 on test set with deviation of 1.0%
# Epoch -10 calculated in  3.69 s
# Epoch 10 MSE 0.087861 on test set with deviation of 0.97%
# Epoch -11 calculated in  3.70 s
# Epoch 11 MSE 0.085747 on test set with deviation of 0.85%
# Epoch -12 calculated in  3.72 s
# Epoch 12 MSE 0.083775 on test set with deviation of 0.57%
# Epoch -13 calculated in  3.72 s
# Epoch 13 MSE 0.081924 on test set with deviation of 0.16%
# Epoch -14 calculated in  3.73 s
# Epoch 14 MSE 0.0802 on test set with deviation of 0.34%
# Epoch -15 calculated in  3.71 s
# Epoch 15 MSE 0.078441 on test set with deviation of 0.76%
# Epoch -16 calculated in  3.73 s
# Epoch 16 MSE 0.076496 on test set with deviation of 0.88%
# Epoch -17 calculated in  3.62 s
# Epoch 17 MSE 0.074558 on test set with deviation of 0.97%
# Epoch -18 calculated in  3.70 s
# Epoch 18 MSE 0.072678 on test set with deviation of 1.2%
# Epoch -19 calculated in  3.70 s
# Epoch 19 MSE 0.070858 on test set with deviation of 1.4%
# Epoch -20 calculated in  3.71 s
# Epoch 20 MSE 0.069146 on test set with deviation of 1.7%
# Epoch -21 calculated in  3.72 s
# Epoch 21 MSE 0.067489 on test set with deviation of 2.0%
# Epoch -22 calculated in  3.84 s
# Epoch 22 MSE 0.065794 on test set with deviation of 2.0%
# Epoch -23 calculated in  3.83 s
# Epoch 23 MSE 0.063981 on test set with deviation of 1.7%
# Epoch -24 calculated in  3.70 s
# Epoch 24 MSE 0.06235 on test set with deviation of 1.5%
# Epoch -25 calculated in  3.76 s
# Epoch 25 MSE 0.061084 on test set with deviation of 1.8%
# Epoch -26 calculated in  3.68 s
# Epoch 26 MSE 0.059971 on test set with deviation of 2.2%
# Epoch -27 calculated in  3.75 s
# Epoch 27 MSE 0.058912 on test set with deviation of 2.4%
# Epoch -28 calculated in  3.64 s
# Epoch 28 MSE 0.057885 on test set with deviation of 2.6%
# Epoch -29 calculated in  3.66 s
# Epoch 29 MSE 0.056895 on test set with deviation of 2.8%
# Epoch -30 calculated in  3.68 s
# Epoch 30 MSE 0.055946 on test set with deviation of 2.9%
# Epoch -31 calculated in  3.66 s
# Epoch 31 MSE 0.055045 on test set with deviation of 3.0%
# Epoch -32 calculated in  3.70 s
# Epoch 32 MSE 0.054195 on test set with deviation of 3.1%
# Epoch -33 calculated in  3.70 s
# Epoch 33 MSE 0.053398 on test set with deviation of 3.1%
# Epoch -34 calculated in  3.68 s
# Epoch 34 MSE 0.052654 on test set with deviation of 3.2%
# Epoch -35 calculated in  3.70 s
# Epoch 35 MSE 0.051964 on test set with deviation of 3.4%
# Epoch -36 calculated in  3.78 s
# Epoch 36 MSE 0.051326 on test set with deviation of 3.5%
# Epoch -37 calculated in  3.81 s
# Epoch 37 MSE 0.050743 on test set with deviation of 3.7%
# Epoch -38 calculated in  3.74 s
# Epoch 38 MSE 0.050213 on test set with deviation of 4.0%
# Epoch -39 calculated in  3.75 s
# Epoch 39 MSE 0.049726 on test set with deviation of 4.3%
# Epoch -40 calculated in  3.87 s
# Epoch 40 MSE 0.049252 on test set with deviation of 4.6%
# Epoch -41 calculated in  3.76 s
# Epoch 41 MSE 0.048769 on test set with deviation of 4.9%
# Epoch -42 calculated in  3.85 s
# Epoch 42 MSE 0.048287 on test set with deviation of 5.2%
# Epoch -43 calculated in  3.83 s
# Epoch 43 MSE 0.047818 on test set with deviation of 5.5%
# Epoch -44 calculated in  3.82 s
# Epoch 44 MSE 0.047367 on test set with deviation of 5.8%
# Epoch -45 calculated in  3.78 s
# Epoch 45 MSE 0.046936 on test set with deviation of 6.1%
# Epoch -46 calculated in  3.66 s
# Epoch 46 MSE 0.046521 on test set with deviation of 6.4%
# Epoch -47 calculated in  3.75 s
# Epoch 47 MSE 0.046112 on test set with deviation of 6.7%
# Epoch -48 calculated in  3.81 s
# Epoch 48 MSE 0.045714 on test set with deviation of 6.9%
# Epoch -49 calculated in  3.82 s
# Epoch 49 MSE 0.045335 on test set with deviation of 7.2%
# Epoch -50 calculated in  3.77 s
# Epoch 50 MSE 0.044984 on test set with deviation of 7.5%
# Epoch -51 calculated in  3.75 s
# Epoch 51 MSE 0.044678 on test set with deviation of 7.9%
# Epoch -52 calculated in  3.70 s
# Epoch 52 MSE 0.04441 on test set with deviation of 8.4%
# Epoch -53 calculated in  3.82 s
# Epoch 53 MSE 0.044124 on test set with deviation of 8.8%
# Epoch -54 calculated in  3.68 s
# Epoch 54 MSE 0.043787 on test set with deviation of 9.1%
# Epoch -55 calculated in  3.70 s
# Epoch 55 MSE 0.04343 on test set with deviation of 9.3%
# Epoch -56 calculated in  3.67 s
# Epoch 56 MSE 0.043072 on test set with deviation of 9.6%
# Epoch -57 calculated in  3.68 s
# Epoch 57 MSE 0.042967 on test set with deviation of 1e+01%
# Epoch -58 calculated in  3.73 s
# Epoch 58 MSE 0.042683 on test set with deviation of 1.1e+01%
# Epoch -59 calculated in  3.73 s
# Epoch 59 MSE 0.04236 on test set with deviation of 1.1e+01%
# Epoch -60 calculated in  3.76 s
# Epoch 60 MSE 0.042202 on test set with deviation of 1.1e+01%
# Epoch -61 calculated in  3.69 s
# Epoch 61 MSE 0.041329 on test set with deviation of 1e+01%
# Epoch -62 calculated in  3.69 s
# Epoch 62 MSE 0.041171 on test set with deviation of 1.1e+01%
# Epoch -63 calculated in  3.70 s
# Epoch 63 MSE 0.040859 on test set with deviation of 1.1e+01%
# Epoch -64 calculated in  3.70 s
# Epoch 64 MSE 0.04066 on test set with deviation of 1.1e+01%
# Epoch -65 calculated in  3.68 s
# Epoch 65 MSE 0.04045 on test set with deviation of 1.2e+01%
# Epoch -66 calculated in  3.72 s
# Epoch 66 MSE 0.040236 on test set with deviation of 1.2e+01%
# Epoch -67 calculated in  3.69 s
# Epoch 67 MSE 0.039602 on test set with deviation of 1.1e+01%
# Epoch -68 calculated in  3.68 s
# Epoch 68 MSE 0.03936 on test set with deviation of 1.1e+01%
# Epoch -69 calculated in  3.67 s
# Epoch 69 MSE 0.039489 on test set with deviation of 1.3e+01%
# Epoch -70 calculated in  3.67 s
# Epoch 70 MSE 0.038935 on test set with deviation of 1.1e+01%
# Epoch -71 calculated in  3.67 s
# Epoch 71 MSE 0.03942 on test set with deviation of 1.4e+01%
# Epoch -72 calculated in  3.68 s
# Epoch 72 MSE 0.038972 on test set with deviation of 1.3e+01%
# Epoch -73 calculated in  3.67 s
# Epoch 73 MSE 0.038583 on test set with deviation of 1.3e+01%
# Epoch -74 calculated in  3.69 s
# Epoch 74 MSE 0.039045 on test set with deviation of 1.5e+01%
# Epoch -75 calculated in  3.67 s
# Epoch 75 MSE 0.039191 on test set with deviation of 1.5e+01%
# Epoch -76 calculated in  3.68 s
# Epoch 76 MSE 0.03803 on test set with deviation of 1.3e+01%
# Epoch -77 calculated in  3.67 s
# Epoch 77 MSE 0.037798 on test set with deviation of 1.2e+01%
# Epoch -78 calculated in  3.66 s
# Epoch 78 MSE 0.038926 on test set with deviation of 1.5e+01%
# Epoch -79 calculated in  3.69 s
# Epoch 79 MSE 0.038702 on test set with deviation of 1.3e+01%
# Epoch -80 calculated in  3.72 s
# Epoch 80 MSE 0.038013 on test set with deviation of 1.4e+01%
# Epoch -81 calculated in  3.67 s
# Epoch 81 MSE 0.038497 on test set with deviation of 1.6e+01%
# Epoch -82 calculated in  3.67 s
# Epoch 82 MSE 0.036518 on test set with deviation of 9.9%
# Epoch -83 calculated in  3.67 s
# Epoch 83 MSE 0.03589 on test set with deviation of 1.1e+01%
# Epoch -84 calculated in  3.69 s
# Epoch 84 MSE 0.035722 on test set with deviation of 1.2e+01%
# Epoch -85 calculated in  3.68 s
# Epoch 85 MSE 0.035401 on test set with deviation of 1.2e+01%
# Epoch -86 calculated in  3.65 s
# Epoch 86 MSE 0.034993 on test set with deviation of 1.2e+01%
# Epoch -87 calculated in  3.70 s
# Epoch 87 MSE 0.034858 on test set with deviation of 1.3e+01%
# Epoch -88 calculated in  3.66 s
# Epoch 88 MSE 0.034633 on test set with deviation of 1.3e+01%
# Epoch -89 calculated in  3.69 s
# Epoch 89 MSE 0.034373 on test set with deviation of 1.3e+01%
# Epoch -90 calculated in  3.63 s
# Epoch 90 MSE 0.03442 on test set with deviation of 1.3e+01%
# Epoch -91 calculated in  3.68 s
# Epoch 91 MSE 0.034628 on test set with deviation of 1.4e+01%
# Epoch -92 calculated in  3.69 s
# Epoch 92 MSE 0.033915 on test set with deviation of 1.2e+01%
# Epoch -93 calculated in  3.65 s
# Epoch 93 MSE 0.034114 on test set with deviation of 1.4e+01%
# Epoch -94 calculated in  3.66 s
# Epoch 94 MSE 0.033887 on test set with deviation of 1.4e+01%
# Epoch -95 calculated in  3.64 s
# Epoch 95 MSE 0.033663 on test set with deviation of 1.3e+01%
# Epoch -96 calculated in  3.69 s
# Epoch 96 MSE 0.034558 on test set with deviation of 1.6e+01%
# Epoch -97 calculated in  3.67 s
# Epoch 97 MSE 0.033611 on test set with deviation of 1.2e+01%
# Epoch -98 calculated in  3.69 s
# Epoch 98 MSE 0.033684 on test set with deviation of 1.3e+01%
# Epoch -99 calculated in  3.68 s
# Epoch 99 MSE 0.033317 on test set with deviation of 1.3e+01%
# Epoch -100 calculated in  3.72 s
# Epoch 100 MSE 0.033468 on test set with deviation of 1.4e+01%
# Epoch -101 calculated in  3.67 s
# Epoch 101 MSE 0.033884 on test set with deviation of 1.6e+01%
# Epoch -102 calculated in  3.67 s
# Epoch 102 MSE 0.035957 on test set with deviation of 2.2e+01%
# Epoch -103 calculated in  3.64 s
# Epoch 103 MSE 0.033616 on test set with deviation of 1.2e+01%
# Epoch -104 calculated in  3.67 s
# Epoch 104 MSE 0.033906 on test set with deviation of 1.7e+01%
# Epoch -105 calculated in  3.63 s
# Epoch 105 MSE 0.032797 on test set with deviation of 1.4e+01%
# Epoch -106 calculated in  3.66 s
# Epoch 106 MSE 0.032609 on test set with deviation of 1.5e+01%
# Epoch -107 calculated in  3.67 s
# Epoch 107 MSE 0.032522 on test set with deviation of 1.6e+01%
# Epoch -108 calculated in  3.69 s
# Epoch 108 MSE 0.032616 on test set with deviation of 1.7e+01%
# Epoch -109 calculated in  3.66 s
# Epoch 109 MSE 0.03216 on test set with deviation of 1.7e+01%
# Epoch -110 calculated in  3.65 s
# Epoch 110 MSE 0.031646 on test set with deviation of 1.6e+01%
# Epoch -111 calculated in  3.68 s
# Epoch 111 MSE 0.031385 on test set with deviation of 1.6e+01%
# Epoch -112 calculated in  3.81 s
# Epoch 112 MSE 0.031168 on test set with deviation of 1.6e+01%
# Epoch -113 calculated in  3.70 s
# Epoch 113 MSE 0.031003 on test set with deviation of 1.6e+01%
# Epoch -114 calculated in  3.81 s
# Epoch 114 MSE 0.034018 on test set with deviation of 2.6e+01%
# Epoch -115 calculated in  3.67 s
# Epoch 115 MSE 0.031096 on test set with deviation of 1.3e+01%
# Epoch -116 calculated in  3.65 s
# Epoch 116 MSE 0.031011 on test set with deviation of 1.6e+01%
# Epoch -117 calculated in  3.66 s
# Epoch 117 MSE 0.030798 on test set with deviation of 1.6e+01%
# Epoch -118 calculated in  3.70 s
# Epoch 118 MSE 0.03072 on test set with deviation of 1.6e+01%
# Epoch -119 calculated in  3.67 s
# Epoch 119 MSE 0.030565 on test set with deviation of 1.6e+01%
# Epoch -120 calculated in  3.68 s
# Epoch 120 MSE 0.030414 on test set with deviation of 1.6e+01%
# Epoch -121 calculated in  3.64 s
# Epoch 121 MSE 0.030221 on test set with deviation of 1.5e+01%
# Epoch -122 calculated in  3.68 s
# Epoch 122 MSE 0.03032 on test set with deviation of 1.4e+01%
# Epoch -123 calculated in  3.69 s
# Epoch 123 MSE 0.031162 on test set with deviation of 9.7%
# Epoch -124 calculated in  3.66 s
# Epoch 124 MSE 0.030607 on test set with deviation of 1.5e+01%
# Epoch -125 calculated in  3.78 s
# Epoch 125 MSE 0.030424 on test set with deviation of 1.6e+01%
# Epoch -126 calculated in  3.65 s
# Epoch 126 MSE 0.030951 on test set with deviation of 1.8e+01%
# Epoch -127 calculated in  3.66 s
# Epoch 127 MSE 0.031695 on test set with deviation of 2.1e+01%
# Epoch -128 calculated in  3.67 s
# Epoch 128 MSE 0.031519 on test set with deviation of 2e+01%
# Epoch -129 calculated in  3.63 s
# Epoch 129 MSE 0.030782 on test set with deviation of 1.8e+01%
# Epoch -130 calculated in  3.72 s
# Epoch 130 MSE 0.03064 on test set with deviation of 1.8e+01%
# Epoch -131 calculated in  3.65 s
# Epoch 131 MSE 0.030152 on test set with deviation of 1.4e+01%
# Epoch -132 calculated in  3.67 s
# Epoch 132 MSE 0.029853 on test set with deviation of 1.4e+01%
# Epoch -133 calculated in  3.65 s
# Epoch 133 MSE 0.029716 on test set with deviation of 1.3e+01%
# Epoch -134 calculated in  3.73 s
# Epoch 134 MSE 0.030066 on test set with deviation of 1.4e+01%
# Epoch -135 calculated in  3.65 s
# Epoch 135 MSE 0.031606 on test set with deviation of 1.8e+01%
# Epoch -136 calculated in  3.64 s
# Epoch 136 MSE 0.03057 on test set with deviation of 1.5e+01%
# Epoch -137 calculated in  3.75 s
# Epoch 137 MSE 0.030017 on test set with deviation of 1.7e+01%
# Epoch -138 calculated in  3.71 s
# Epoch 138 MSE 0.029553 on test set with deviation of 1.7e+01%
# Epoch -139 calculated in  3.65 s
# Epoch 139 MSE 0.029212 on test set with deviation of 1.7e+01%
# Epoch -140 calculated in  3.73 s
# Epoch 140 MSE 0.028996 on test set with deviation of 1.8e+01%
# Epoch -141 calculated in  3.66 s
# Epoch 141 MSE 0.028972 on test set with deviation of 1.9e+01%
# Epoch -142 calculated in  3.67 s
# Epoch 142 MSE 0.028903 on test set with deviation of 2e+01%
# Epoch -143 calculated in  3.67 s
# Epoch 143 MSE 0.028798 on test set with deviation of 2e+01%
# Epoch -144 calculated in  3.65 s
# Epoch 144 MSE 0.028637 on test set with deviation of 2e+01%
# Epoch -145 calculated in  3.66 s
# Epoch 145 MSE 0.028579 on test set with deviation of 2e+01%
# Epoch -146 calculated in  3.63 s
# Epoch 146 MSE 0.028457 on test set with deviation of 2e+01%
# Epoch -147 calculated in  3.65 s
# Epoch 147 MSE 0.028298 on test set with deviation of 1.9e+01%
# Epoch -148 calculated in  3.64 s
# Epoch 148 MSE 0.028207 on test set with deviation of 1.9e+01%
# Epoch -149 calculated in  3.64 s
# Epoch 149 MSE 0.028163 on test set with deviation of 2e+01%
# Epoch -150 calculated in  3.64 s
# Epoch 150 MSE 0.028162 on test set with deviation of 2e+01%
# Epoch -151 calculated in  3.66 s
# Epoch 151 MSE 0.029192 on test set with deviation of 1.3e+01%
# Epoch -152 calculated in  3.65 s
# Epoch 152 MSE 0.02818 on test set with deviation of 1.8e+01%
# Epoch -153 calculated in  3.65 s
# Epoch 153 MSE 0.027955 on test set with deviation of 1.8e+01%
# Epoch -154 calculated in  3.67 s
# Epoch 154 MSE 0.027825 on test set with deviation of 1.7e+01%
# Epoch -155 calculated in  3.64 s
# Epoch 155 MSE 0.028019 on test set with deviation of 1.8e+01%
# Epoch -156 calculated in  3.69 s
# Epoch 156 MSE 0.02905 on test set with deviation of 2.3e+01%
# Epoch -157 calculated in  3.65 s
# Epoch 157 MSE 0.027977 on test set with deviation of 1.8e+01%
# Epoch -158 calculated in  3.63 s
# Epoch 158 MSE 0.0278 on test set with deviation of 1.9e+01%
# Epoch -159 calculated in  3.66 s
# Epoch 159 MSE 0.027749 on test set with deviation of 2e+01%
# Epoch -160 calculated in  3.69 s
# Epoch 160 MSE 0.027686 on test set with deviation of 2.1e+01%
# Epoch -161 calculated in  3.63 s
# Epoch 161 MSE 0.027566 on test set with deviation of 2.1e+01%
# Epoch -162 calculated in  3.63 s
# Epoch 162 MSE 0.02744 on test set with deviation of 2.1e+01%
# Epoch -163 calculated in  3.64 s
# Epoch 163 MSE 0.027366 on test set with deviation of 2.2e+01%
# Epoch -164 calculated in  3.63 s
# Epoch 164 MSE 0.027323 on test set with deviation of 2.2e+01%
# Epoch -165 calculated in  3.61 s
# Epoch 165 MSE 0.027239 on test set with deviation of 2.2e+01%
# Epoch -166 calculated in  3.66 s
# Epoch 166 MSE 0.027074 on test set with deviation of 2.1e+01%
# Epoch -167 calculated in  3.63 s
# Epoch 167 MSE 0.026999 on test set with deviation of 2.1e+01%
# Epoch -168 calculated in  3.62 s
# Epoch 168 MSE 0.02694 on test set with deviation of 2.1e+01%
# Epoch -169 calculated in  3.64 s
# Epoch 169 MSE 0.026886 on test set with deviation of 2.1e+01%
# Epoch -170 calculated in  3.62 s
# Epoch 170 MSE 0.026837 on test set with deviation of 2.1e+01%
# Epoch -171 calculated in  3.66 s
# Epoch 171 MSE 0.026812 on test set with deviation of 2.1e+01%
# Epoch -172 calculated in  3.64 s
# Epoch 172 MSE 0.026853 on test set with deviation of 2.1e+01%
# Epoch -173 calculated in  3.64 s
# Epoch 173 MSE 0.026953 on test set with deviation of 2.2e+01%
# Epoch -174 calculated in  3.64 s
# Epoch 174 MSE 0.027152 on test set with deviation of 2.3e+01%
# Epoch -175 calculated in  3.65 s
# Epoch 175 MSE 0.027275 on test set with deviation of 2.3e+01%
# Epoch -176 calculated in  3.64 s
# Epoch 176 MSE 0.027674 on test set with deviation of 2e+01%
# Epoch -177 calculated in  3.64 s
# Epoch 177 MSE 0.027947 on test set with deviation of 1.4e+01%
# Epoch -178 calculated in  3.63 s
# Epoch 178 MSE 0.02791 on test set with deviation of 1.9e+01%
# Epoch -179 calculated in  3.66 s
# Epoch 179 MSE 0.027694 on test set with deviation of 2.1e+01%
# Epoch -180 calculated in  3.67 s
# Epoch 180 MSE 0.026634 on test set with deviation of 1.7e+01%
# Epoch -181 calculated in  3.64 s
# Epoch 181 MSE 0.026377 on test set with deviation of 1.7e+01%
# Epoch -182 calculated in  3.62 s
# Epoch 182 MSE 0.026354 on test set with deviation of 1.8e+01%
# Epoch -183 calculated in  3.61 s
# Epoch 183 MSE 0.026363 on test set with deviation of 1.9e+01%
# Epoch -184 calculated in  3.64 s
# Epoch 184 MSE 0.026412 on test set with deviation of 1.9e+01%
# Epoch -185 calculated in  3.64 s
# Epoch 185 MSE 0.026523 on test set with deviation of 1.8e+01%
# Epoch -186 calculated in  3.63 s
# Epoch 186 MSE 0.026727 on test set with deviation of 1.9e+01%
# Epoch -187 calculated in  3.61 s
# Epoch 187 MSE 0.027153 on test set with deviation of 2e+01%
# Epoch -188 calculated in  3.64 s
# Epoch 188 MSE 0.027219 on test set with deviation of 2.2e+01%
# Epoch -189 calculated in  3.63 s
# Epoch 189 MSE 0.02681 on test set with deviation of 2.2e+01%
# Epoch -190 calculated in  3.65 s
# Epoch 190 MSE 0.026422 on test set with deviation of 2.2e+01%
# Epoch -191 calculated in  3.63 s
# Epoch 191 MSE 0.026049 on test set with deviation of 2.2e+01%
# Epoch -192 calculated in  3.66 s
# Epoch 192 MSE 0.025843 on test set with deviation of 2.2e+01%
# Epoch -193 calculated in  3.62 s
# Epoch 193 MSE 0.025783 on test set with deviation of 2.3e+01%
# Epoch -194 calculated in  3.66 s
# Epoch 194 MSE 0.02585 on test set with deviation of 2.5e+01%
# Epoch -195 calculated in  3.62 s
# Epoch 195 MSE 0.025734 on test set with deviation of 2.5e+01%
# Epoch -196 calculated in  3.61 s
# Epoch 196 MSE 0.025543 on test set with deviation of 2.4e+01%
# Epoch -197 calculated in  3.63 s
# Epoch 197 MSE 0.025429 on test set with deviation of 2.4e+01%
# Epoch -198 calculated in  3.65 s
# Epoch 198 MSE 0.025364 on test set with deviation of 2.4e+01%
# Epoch -199 calculated in  3.62 s
# Epoch 199 MSE 0.025333 on test set with deviation of 2.3e+01%
# Epoch -200 calculated in  3.65 s
# Epoch 200 MSE 0.02532 on test set with deviation of 2.3e+01%
# Epoch -201 calculated in  3.63 s
# Epoch 201 MSE 0.025452 on test set with deviation of 2.3e+01%
# Epoch -202 calculated in  3.66 s
# Epoch 202 MSE 0.026594 on test set with deviation of 2.7e+01%
# Epoch -203 calculated in  3.65 s
# Epoch 203 MSE 0.028903 on test set with deviation of 2.3e+01%
# Epoch -204 calculated in  3.62 s
# Epoch 204 MSE 0.026209 on test set with deviation of 1.9e+01%
# Epoch -205 calculated in  3.65 s
# Epoch 205 MSE 0.025951 on test set with deviation of 2.3e+01%
# Epoch -206 calculated in  3.65 s
# Epoch 206 MSE 0.025534 on test set with deviation of 2.1e+01%
# Epoch -207 calculated in  3.64 s
# Epoch 207 MSE 0.025442 on test set with deviation of 2.2e+01%
# Epoch -208 calculated in  3.63 s
# Epoch 208 MSE 0.025264 on test set with deviation of 2.2e+01%
# Epoch -209 calculated in  3.66 s
# Epoch 209 MSE 0.025147 on test set with deviation of 2.3e+01%
# Epoch -210 calculated in  3.64 s
# Epoch 210 MSE 0.025088 on test set with deviation of 2.3e+01%
# Epoch -211 calculated in  3.62 s
# Epoch 211 MSE 0.025032 on test set with deviation of 2.4e+01%
# Epoch -212 calculated in  3.65 s
# Epoch 212 MSE 0.024994 on test set with deviation of 2.5e+01%
# Epoch -213 calculated in  3.60 s
# Epoch 213 MSE 0.024964 on test set with deviation of 2.6e+01%
# Epoch -214 calculated in  3.63 s
# Epoch 214 MSE 0.024963 on test set with deviation of 2.7e+01%
# Epoch -215 calculated in  3.64 s
# Epoch 215 MSE 0.025044 on test set with deviation of 2.7e+01%
# Epoch -216 calculated in  3.63 s
# Epoch 216 MSE 0.0248 on test set with deviation of 2.6e+01%
# Epoch -217 calculated in  3.64 s
# Epoch 217 MSE 0.02468 on test set with deviation of 2.6e+01%
# Epoch -218 calculated in  3.65 s
# Epoch 218 MSE 0.024619 on test set with deviation of 2.5e+01%
# Epoch -219 calculated in  3.64 s
# Epoch 219 MSE 0.024578 on test set with deviation of 2.5e+01%
# Epoch -220 calculated in  3.66 s
# Epoch 220 MSE 0.024563 on test set with deviation of 2.5e+01%
# Epoch -221 calculated in  3.64 s
# Epoch 221 MSE 0.024672 on test set with deviation of 2.5e+01%
# Epoch -222 calculated in  3.65 s
# Epoch 222 MSE 0.025879 on test set with deviation of 2.6e+01%
# Epoch -223 calculated in  3.62 s
# Epoch 223 MSE 0.025655 on test set with deviation of 2.3e+01%
# Epoch -224 calculated in  3.64 s
# Epoch 224 MSE 0.025023 on test set with deviation of 2.2e+01%
# Epoch -225 calculated in  3.65 s
# Epoch 225 MSE 0.024974 on test set with deviation of 2.4e+01%
# Epoch -226 calculated in  3.64 s
# Epoch 226 MSE 0.024804 on test set with deviation of 2.4e+01%
# Epoch -227 calculated in  3.65 s
# Epoch 227 MSE 0.024587 on test set with deviation of 2.2e+01%
# Epoch -228 calculated in  3.62 s
# Epoch 228 MSE 0.024794 on test set with deviation of 2.2e+01%
# Epoch -229 calculated in  3.64 s
# Epoch 229 MSE 0.025395 on test set with deviation of 2.3e+01%
# Epoch -230 calculated in  3.66 s
# Epoch 230 MSE 0.026085 on test set with deviation of 2.4e+01%
# Epoch -231 calculated in  3.65 s
# Epoch 231 MSE 0.027305 on test set with deviation of 2.8e+01%
# Epoch -232 calculated in  3.66 s
# Epoch 232 MSE 0.027549 on test set with deviation of 3e+01%
# Epoch -233 calculated in  3.65 s
# Epoch 233 MSE 0.02766 on test set with deviation of 3.2e+01%
# Epoch -234 calculated in  3.62 s
# Epoch 234 MSE 0.026869 on test set with deviation of 2.3e+01%
# Epoch -235 calculated in  3.65 s
# Epoch 235 MSE 0.026732 on test set with deviation of 2.8e+01%
# Epoch -236 calculated in  3.63 s
# Epoch 236 MSE 0.026513 on test set with deviation of 2.9e+01%
# Epoch -237 calculated in  3.65 s
# Epoch 237 MSE 0.026275 on test set with deviation of 2.9e+01%
# Epoch -238 calculated in  3.67 s
# Epoch 238 MSE 0.025982 on test set with deviation of 3e+01%
# Epoch -239 calculated in  3.66 s
# Epoch 239 MSE 0.02557 on test set with deviation of 3e+01%
# Epoch -240 calculated in  3.69 s
# Epoch 240 MSE 0.025072 on test set with deviation of 2.9e+01%
# Epoch -241 calculated in  3.62 s
# Epoch 241 MSE 0.024655 on test set with deviation of 2.9e+01%
# Epoch -242 calculated in  3.59 s
# Epoch 242 MSE 0.024339 on test set with deviation of 2.9e+01%
# Epoch -243 calculated in  3.66 s
# Epoch 243 MSE 0.024113 on test set with deviation of 2.9e+01%
# Epoch -244 calculated in  3.67 s
# Epoch 244 MSE 0.024083 on test set with deviation of 2.9e+01%
# Epoch -245 calculated in  3.64 s
# Epoch 245 MSE 0.023895 on test set with deviation of 2.8e+01%
# Epoch -246 calculated in  3.65 s
# Epoch 246 MSE 0.023762 on test set with deviation of 2.8e+01%
# Epoch -247 calculated in  3.65 s
# Epoch 247 MSE 0.023663 on test set with deviation of 2.7e+01%
# Epoch -248 calculated in  3.67 s
# Epoch 248 MSE 0.023606 on test set with deviation of 2.7e+01%
# Epoch -249 calculated in  3.64 s
# Epoch 249 MSE 0.023575 on test set with deviation of 2.7e+01%
# Epoch -250 calculated in  3.64 s
# Epoch 250 MSE 0.023538 on test set with deviation of 2.6e+01%
# Epoch -251 calculated in  3.63 s
# Epoch 251 MSE 0.023507 on test set with deviation of 2.6e+01%
# Epoch -252 calculated in  3.65 s
# Epoch 252 MSE 0.023534 on test set with deviation of 2.6e+01%
# Epoch -253 calculated in  3.62 s
# Epoch 253 MSE 0.02416 on test set with deviation of 2.6e+01%
# Epoch -254 calculated in  3.65 s
# Epoch 254 MSE 0.024425 on test set with deviation of 2.7e+01%
# Epoch -255 calculated in  3.64 s
# Epoch 255 MSE 0.024099 on test set with deviation of 2.5e+01%
# Epoch -256 calculated in  3.63 s
# Epoch 256 MSE 0.024323 on test set with deviation of 2.7e+01%
# Epoch -257 calculated in  3.62 s
# Epoch 257 MSE 0.024232 on test set with deviation of 2.5e+01%
# Epoch -258 calculated in  3.63 s
# Epoch 258 MSE 0.026206 on test set with deviation of 3.1e+01%
# Epoch -259 calculated in  3.60 s
# Epoch 259 MSE 0.025563 on test set with deviation of 2e+01%
# Epoch -260 calculated in  3.67 s
# Epoch 260 MSE 0.025733 on test set with deviation of 2.6e+01%
# Epoch -261 calculated in  3.62 s
# Epoch 261 MSE 0.025684 on test set with deviation of 3e+01%
# Epoch -262 calculated in  3.65 s
# Epoch 262 MSE 0.025683 on test set with deviation of 3.2e+01%
# Epoch -263 calculated in  3.64 s
# Epoch 263 MSE 0.025373 on test set with deviation of 3.2e+01%
# Epoch -264 calculated in  3.64 s
# Epoch 264 MSE 0.02498 on test set with deviation of 3.2e+01%
# Epoch -265 calculated in  3.63 s
# Epoch 265 MSE 0.024546 on test set with deviation of 3.2e+01%
# Epoch -266 calculated in  3.64 s
# Epoch 266 MSE 0.024135 on test set with deviation of 3.1e+01%
# Epoch -267 calculated in  3.63 s
# Epoch 267 MSE 0.023822 on test set with deviation of 3.1e+01%
# Epoch -268 calculated in  3.64 s
# Epoch 268 MSE 0.023627 on test set with deviation of 3.1e+01%
# Epoch -269 calculated in  3.64 s
# Epoch 269 MSE 0.023454 on test set with deviation of 3.1e+01%
# Epoch -270 calculated in  3.66 s
# Epoch 270 MSE 0.023372 on test set with deviation of 3.1e+01%
# Epoch -271 calculated in  3.67 s
# Epoch 271 MSE 0.023321 on test set with deviation of 3.1e+01%
# Epoch -272 calculated in  3.63 s
# Epoch 272 MSE 0.023164 on test set with deviation of 3e+01%
# Epoch -273 calculated in  3.64 s
# Epoch 273 MSE 0.023069 on test set with deviation of 2.9e+01%
# Epoch -274 calculated in  3.64 s
# Epoch 274 MSE 0.023002 on test set with deviation of 2.9e+01%
# Epoch -275 calculated in  3.61 s
# Epoch 275 MSE 0.023025 on test set with deviation of 2.9e+01%
# Epoch -276 calculated in  3.62 s
# Epoch 276 MSE 0.022997 on test set with deviation of 2.8e+01%
# Epoch -277 calculated in  3.64 s
# Epoch 277 MSE 0.022962 on test set with deviation of 2.8e+01%
# Epoch -278 calculated in  3.63 s
# Epoch 278 MSE 0.02296 on test set with deviation of 2.8e+01%
# Epoch -279 calculated in  3.64 s
# Epoch 279 MSE 0.023014 on test set with deviation of 2.9e+01%
# Epoch -280 calculated in  3.69 s
# Epoch 280 MSE 0.023569 on test set with deviation of 3.1e+01%
# Epoch -281 calculated in  3.66 s
# Epoch 281 MSE 0.025608 on test set with deviation of 3.3e+01%
# Epoch -282 calculated in  3.64 s
# Epoch 282 MSE 0.02618 on test set with deviation of 1.6e+01%
# Epoch -283 calculated in  3.63 s
# Epoch 283 MSE 0.024244 on test set with deviation of 2.6e+01%
# Epoch -284 calculated in  3.64 s
# Epoch 284 MSE 0.02398 on test set with deviation of 2.9e+01%
# Epoch -285 calculated in  3.63 s
# Epoch 285 MSE 0.023971 on test set with deviation of 3e+01%
# Epoch -286 calculated in  3.66 s
# Epoch 286 MSE 0.024023 on test set with deviation of 3.1e+01%
# Epoch -287 calculated in  3.65 s
# Epoch 287 MSE 0.023979 on test set with deviation of 3.2e+01%
# Epoch -288 calculated in  3.64 s
# Epoch 288 MSE 0.023892 on test set with deviation of 3.2e+01%
# Epoch -289 calculated in  3.63 s
# Epoch 289 MSE 0.023814 on test set with deviation of 3.3e+01%
# Epoch -290 calculated in  3.63 s
# Epoch 290 MSE 0.023603 on test set with deviation of 3.3e+01%
# Epoch -291 calculated in  3.63 s
# Epoch 291 MSE 0.023463 on test set with deviation of 3.3e+01%
# Epoch -292 calculated in  3.64 s
# Epoch 292 MSE 0.02332 on test set with deviation of 3.3e+01%
# Epoch -293 calculated in  3.64 s
# Epoch 293 MSE 0.023183 on test set with deviation of 3.3e+01%
# Epoch -294 calculated in  3.64 s
# Epoch 294 MSE 0.023064 on test set with deviation of 3.3e+01%
# Epoch -295 calculated in  3.64 s
# Epoch 295 MSE 0.023046 on test set with deviation of 3.3e+01%
# Epoch -296 calculated in  3.63 s
# Epoch 296 MSE 0.022964 on test set with deviation of 3.2e+01%
# Epoch -297 calculated in  3.65 s
# Epoch 297 MSE 0.022825 on test set with deviation of 3.2e+01%
# Epoch -298 calculated in  3.64 s
# Epoch 298 MSE 0.022727 on test set with deviation of 3.2e+01%
# Epoch -299 calculated in  3.64 s
# Epoch 299 MSE 0.022661 on test set with deviation of 3.1e+01%
# Epoch -300 calculated in  3.66 s
# Epoch 300 MSE 0.022649 on test set with deviation of 3.1e+01%
# Epoch -301 calculated in  3.66 s
# Epoch 301 MSE 0.02262 on test set with deviation of 3.1e+01%
# Epoch -302 calculated in  3.64 s
# Epoch 302 MSE 0.022639 on test set with deviation of 3.1e+01%
# Epoch -303 calculated in  3.63 s
# Epoch 303 MSE 0.022638 on test set with deviation of 3.1e+01%
# Epoch -304 calculated in  3.65 s
# Epoch 304 MSE 0.022704 on test set with deviation of 3.1e+01%
# Epoch -305 calculated in  3.64 s
# Epoch 305 MSE 0.023001 on test set with deviation of 3.1e+01%
# Epoch -306 calculated in  3.62 s
# Epoch 306 MSE 0.028239 on test set with deviation of 4.4e+01%
# Epoch -307 calculated in  3.64 s
# Epoch 307 MSE 0.024342 on test set with deviation of 2.1e+01%
# Epoch -308 calculated in  3.64 s
# Epoch 308 MSE 0.02423 on test set with deviation of 2.7e+01%
# Epoch -309 calculated in  3.64 s
# Epoch 309 MSE 0.024099 on test set with deviation of 3.2e+01%
# Epoch -310 calculated in  3.65 s
# Epoch 310 MSE 0.02426 on test set with deviation of 3.2e+01%
# Epoch -311 calculated in  3.63 s
# Epoch 311 MSE 0.024917 on test set with deviation of 3.1e+01%
# Epoch -312 calculated in  3.64 s
# Epoch 312 MSE 0.032982 on test set with deviation of 6.1e+01%
# Epoch -313 calculated in  3.63 s
# Epoch 313 MSE 0.026589 on test set with deviation of 3.2e+01%
# Epoch -314 calculated in  3.61 s
# Epoch 314 MSE 0.025743 on test set with deviation of 3.5e+01%
# Epoch -315 calculated in  3.66 s
# Epoch 315 MSE 0.025273 on test set with deviation of 3.5e+01%
# Epoch -316 calculated in  3.62 s
# Epoch 316 MSE 0.024969 on test set with deviation of 3.6e+01%
# Epoch -317 calculated in  3.65 s
# Epoch 317 MSE 0.024714 on test set with deviation of 3.6e+01%
# Epoch -318 calculated in  3.64 s
# Epoch 318 MSE 0.024396 on test set with deviation of 3.6e+01%
# Epoch -319 calculated in  3.64 s
# Epoch 319 MSE 0.024053 on test set with deviation of 3.6e+01%
# Epoch -320 calculated in  3.68 s
# Epoch 320 MSE 0.023751 on test set with deviation of 3.6e+01%
# Epoch -321 calculated in  3.61 s
# Epoch 321 MSE 0.023491 on test set with deviation of 3.7e+01%
# Epoch -322 calculated in  3.61 s
# Epoch 322 MSE 0.023313 on test set with deviation of 3.7e+01%
# Epoch -323 calculated in  3.62 s
# Epoch 323 MSE 0.023089 on test set with deviation of 3.7e+01%
# Epoch -324 calculated in  3.65 s
# Epoch 324 MSE 0.022848 on test set with deviation of 3.6e+01%
# Epoch -325 calculated in  3.65 s
# Epoch 325 MSE 0.022671 on test set with deviation of 3.5e+01%
# Epoch -326 calculated in  3.64 s
# Epoch 326 MSE 0.022478 on test set with deviation of 3.5e+01%
# Epoch -327 calculated in  3.64 s
# Epoch 327 MSE 0.022354 on test set with deviation of 3.4e+01%
# Epoch -328 calculated in  3.61 s
# Epoch 328 MSE 0.022262 on test set with deviation of 3.4e+01%
# Epoch -329 calculated in  3.63 s
# Epoch 329 MSE 0.022231 on test set with deviation of 3.4e+01%
# Epoch -330 calculated in  3.66 s
# Epoch 330 MSE 0.022228 on test set with deviation of 3.3e+01%
# Epoch -331 calculated in  3.65 s
# Epoch 331 MSE 0.02222 on test set with deviation of 3.3e+01%
# Epoch -332 calculated in  3.65 s
# Epoch 332 MSE 0.022246 on test set with deviation of 3.3e+01%
# Epoch -333 calculated in  3.65 s
# Epoch 333 MSE 0.022272 on test set with deviation of 3.3e+01%
# Epoch -334 calculated in  3.64 s
# Epoch 334 MSE 0.022634 on test set with deviation of 3.1e+01%
# Epoch -335 calculated in  3.63 s
# Epoch 335 MSE 0.024429 on test set with deviation of 3.3e+01%
# Epoch -336 calculated in  3.64 s
# Epoch 336 MSE 0.023763 on test set with deviation of 1.4e+01%
# Epoch -337 calculated in  3.61 s
# Epoch 337 MSE 0.023045 on test set with deviation of 2.9e+01%
# Epoch -338 calculated in  3.62 s
# Epoch 338 MSE 0.022973 on test set with deviation of 3.4e+01%
# Epoch -339 calculated in  3.63 s
# Epoch 339 MSE 0.022999 on test set with deviation of 3.5e+01%
# Epoch -340 calculated in  3.72 s
# Epoch 340 MSE 0.022977 on test set with deviation of 3.5e+01%
# Epoch -341 calculated in  3.61 s
# Epoch 341 MSE 0.023417 on test set with deviation of 3.4e+01%
# Epoch -342 calculated in  3.63 s
# Epoch 342 MSE 0.024036 on test set with deviation of 3.1e+01%
# Epoch -343 calculated in  3.61 s
# Epoch 343 MSE 0.024335 on test set with deviation of 3.6e+01%
# Epoch -344 calculated in  3.67 s
# Epoch 344 MSE 0.024196 on test set with deviation of 3.6e+01%
# Epoch -345 calculated in  3.62 s
# Epoch 345 MSE 0.024314 on test set with deviation of 3.6e+01%
# Epoch -346 calculated in  3.65 s
# Epoch 346 MSE 0.024544 on test set with deviation of 3.6e+01%
# Epoch -347 calculated in  3.63 s
# Epoch 347 MSE 0.02489 on test set with deviation of 3.7e+01%
# Epoch -348 calculated in  3.67 s
# Epoch 348 MSE 0.025219 on test set with deviation of 4e+01%
# Epoch -349 calculated in  3.66 s
# Epoch 349 MSE 0.025258 on test set with deviation of 4.1e+01%
# Epoch -350 calculated in  3.62 s
# Epoch 350 MSE 0.024931 on test set with deviation of 4.1e+01%
# Epoch -351 calculated in  3.64 s
# Epoch 351 MSE 0.024513 on test set with deviation of 3.9e+01%
# Epoch -352 calculated in  3.62 s
# Epoch 352 MSE 0.024118 on test set with deviation of 3.8e+01%
# Epoch -353 calculated in  3.64 s
# Epoch 353 MSE 0.023756 on test set with deviation of 3.8e+01%
# Epoch -354 calculated in  3.64 s
# Epoch 354 MSE 0.023423 on test set with deviation of 3.8e+01%
# Epoch -355 calculated in  3.65 s
# Epoch 355 MSE 0.023159 on test set with deviation of 3.8e+01%
# Epoch -356 calculated in  3.64 s
# Epoch 356 MSE 0.022936 on test set with deviation of 3.9e+01%
# Epoch -357 calculated in  3.64 s
# Epoch 357 MSE 0.022755 on test set with deviation of 3.9e+01%
# Epoch -358 calculated in  3.60 s
# Epoch 358 MSE 0.02255 on test set with deviation of 3.8e+01%
# Epoch -359 calculated in  3.65 s
# Epoch 359 MSE 0.022343 on test set with deviation of 3.8e+01%
# Epoch -360 calculated in  3.67 s
# Epoch 360 MSE 0.022219 on test set with deviation of 3.7e+01%
# Epoch -361 calculated in  3.64 s
# Epoch 361 MSE 0.022133 on test set with deviation of 3.7e+01%
# Epoch -362 calculated in  3.66 s
# Epoch 362 MSE 0.022106 on test set with deviation of 3.7e+01%
# Epoch -363 calculated in  3.64 s
# Epoch 363 MSE 0.022036 on test set with deviation of 3.6e+01%
# Epoch -364 calculated in  3.64 s
# Epoch 364 MSE 0.022072 on test set with deviation of 3.6e+01%
# Epoch -365 calculated in  3.62 s
# Epoch 365 MSE 0.024939 on test set with deviation of 1.9e+01%
# Epoch -366 calculated in  3.66 s
# Epoch 366 MSE 0.022842 on test set with deviation of 2.6e+01%
# Epoch -367 calculated in  3.64 s
# Epoch 367 MSE 0.02242 on test set with deviation of 3.4e+01%
# Epoch -368 calculated in  3.63 s
# Epoch 368 MSE 0.02235 on test set with deviation of 3.7e+01%
# Epoch -369 calculated in  3.65 s
# Epoch 369 MSE 0.022237 on test set with deviation of 3.8e+01%
# Epoch -370 calculated in  3.63 s
# Epoch 370 MSE 0.02212 on test set with deviation of 3.8e+01%
# Epoch -371 calculated in  3.64 s
# Epoch 371 MSE 0.022004 on test set with deviation of 3.8e+01%
# Epoch -372 calculated in  3.64 s
# Epoch 372 MSE 0.021913 on test set with deviation of 3.7e+01%
# Epoch -373 calculated in  3.64 s
# Epoch 373 MSE 0.021891 on test set with deviation of 3.7e+01%
# Epoch -374 calculated in  3.63 s
# Epoch 374 MSE 0.021857 on test set with deviation of 3.7e+01%
# Epoch -375 calculated in  3.62 s
# Epoch 375 MSE 0.021868 on test set with deviation of 3.7e+01%
# Epoch -376 calculated in  3.64 s
# Epoch 376 MSE 0.021893 on test set with deviation of 3.7e+01%
# Epoch -377 calculated in  3.66 s
# Epoch 377 MSE 0.0219 on test set with deviation of 3.7e+01%
# Epoch -378 calculated in  3.62 s
# Epoch 378 MSE 0.021957 on test set with deviation of 3.6e+01%
# Epoch -379 calculated in  3.64 s
# Epoch 379 MSE 0.022541 on test set with deviation of 3.5e+01%
# Epoch -380 calculated in  3.68 s
# Epoch 380 MSE 0.024097 on test set with deviation of 1.1e+01%
# Epoch -381 calculated in  3.61 s
# Epoch 381 MSE 0.022598 on test set with deviation of 2.6e+01%
# Epoch -382 calculated in  3.60 s
# Epoch 382 MSE 0.022928 on test set with deviation of 3.4e+01%
# Epoch -383 calculated in  3.58 s
# Epoch 383 MSE 0.022812 on test set with deviation of 3.3e+01%
# Epoch -384 calculated in  3.57 s
# Epoch 384 MSE 0.023524 on test set with deviation of 3.4e+01%
# Epoch -385 calculated in  3.58 s
# Epoch 385 MSE 0.023076 on test set with deviation of 3.2e+01%
# Epoch -386 calculated in  3.57 s
# Epoch 386 MSE 0.023282 on test set with deviation of 3.4e+01%
# Epoch -387 calculated in  3.58 s
# Epoch 387 MSE 0.023511 on test set with deviation of 3.6e+01%
# Epoch -388 calculated in  3.57 s
# Epoch 388 MSE 0.023697 on test set with deviation of 3.8e+01%
# Epoch -389 calculated in  3.56 s
# Epoch 389 MSE 0.023741 on test set with deviation of 3.9e+01%
# Epoch -390 calculated in  3.56 s
# Epoch 390 MSE 0.023624 on test set with deviation of 3.9e+01%
# Epoch -391 calculated in  3.57 s
# Epoch 391 MSE 0.023378 on test set with deviation of 3.9e+01%
# Epoch -392 calculated in  3.56 s
# Epoch 392 MSE 0.023099 on test set with deviation of 3.8e+01%
# Epoch -393 calculated in  3.54 s
# Epoch 393 MSE 0.022853 on test set with deviation of 3.8e+01%
# Epoch -394 calculated in  3.55 s
# Epoch 394 MSE 0.022639 on test set with deviation of 3.8e+01%
# Epoch -395 calculated in  3.55 s
# Epoch 395 MSE 0.022454 on test set with deviation of 3.8e+01%
# Epoch -396 calculated in  3.56 s
# Epoch 396 MSE 0.022312 on test set with deviation of 3.9e+01%
# Epoch -397 calculated in  3.56 s
# Epoch 397 MSE 0.022149 on test set with deviation of 3.9e+01%
# Epoch -398 calculated in  3.53 s
# Epoch 398 MSE 0.022 on test set with deviation of 3.9e+01%
# Epoch -399 calculated in  3.56 s
# Epoch 399 MSE 0.021862 on test set with deviation of 3.9e+01%
# Epoch -400 calculated in  3.61 s
# Epoch 400 MSE 0.021812 on test set with deviation of 3.9e+01%
# Epoch -401 calculated in  3.56 s
# Epoch 401 MSE 0.021753 on test set with deviation of 3.9e+01%
# Epoch -402 calculated in  3.57 s
# Epoch 402 MSE 0.021767 on test set with deviation of 4e+01%
# Epoch -403 calculated in  3.54 s
# Epoch 403 MSE 0.021652 on test set with deviation of 3.9e+01%
# Epoch -404 calculated in  3.57 s
# Epoch 404 MSE 0.021797 on test set with deviation of 3.9e+01%
# Epoch -405 calculated in  3.54 s
# Epoch 405 MSE 0.022187 on test set with deviation of 3.9e+01%
# Epoch -406 calculated in  3.57 s
# Epoch 406 MSE 0.022399 on test set with deviation of 3.7e+01%
# Epoch -407 calculated in  3.54 s
# Epoch 407 MSE 0.022432 on test set with deviation of 1.3e+01%
# Epoch -408 calculated in  3.57 s
# Epoch 408 MSE 0.022013 on test set with deviation of 3.2e+01%
# Epoch -409 calculated in  3.54 s
# Epoch 409 MSE 0.022221 on test set with deviation of 3.6e+01%
# Epoch -410 calculated in  3.55 s
# Epoch 410 MSE 0.022272 on test set with deviation of 3.7e+01%
# Epoch -411 calculated in  3.54 s
# Epoch 411 MSE 0.022272 on test set with deviation of 3.6e+01%
# Epoch -412 calculated in  3.54 s
# Epoch 412 MSE 0.022517 on test set with deviation of 3.6e+01%
# Epoch -413 calculated in  3.53 s
# Epoch 413 MSE 0.02318 on test set with deviation of 3.8e+01%
# Epoch -414 calculated in  3.56 s
# Epoch 414 MSE 0.022727 on test set with deviation of 3.4e+01%
# Epoch -415 calculated in  3.58 s
# Epoch 415 MSE 0.022389 on test set with deviation of 3.5e+01%
# Epoch -416 calculated in  3.53 s
# Epoch 416 MSE 0.022196 on test set with deviation of 3.4e+01%
# Epoch -417 calculated in  3.57 s
# Epoch 417 MSE 0.022236 on test set with deviation of 3.3e+01%
# Epoch -418 calculated in  3.51 s
# Epoch 418 MSE 0.022421 on test set with deviation of 3.4e+01%
# Epoch -419 calculated in  3.54 s
# Epoch 419 MSE 0.022793 on test set with deviation of 3.7e+01%
# Epoch -420 calculated in  3.62 s
# Epoch 420 MSE 0.023161 on test set with deviation of 4e+01%
# Epoch -421 calculated in  3.53 s
# Epoch 421 MSE 0.023223 on test set with deviation of 4.1e+01%
# Epoch -422 calculated in  3.54 s
# Epoch 422 MSE 0.023106 on test set with deviation of 4e+01%
# Epoch -423 calculated in  3.57 s
# Epoch 423 MSE 0.02287 on test set with deviation of 3.8e+01%
# Epoch -424 calculated in  3.56 s
# Epoch 424 MSE 0.022412 on test set with deviation of 3.4e+01%
# Epoch -425 calculated in  3.58 s
# Epoch 425 MSE 0.021885 on test set with deviation of 2.6e+01%
# Epoch -426 calculated in  3.56 s
# Epoch 426 MSE 0.023502 on test set with deviation of 2.7e+01%
# Epoch -427 calculated in  3.53 s
# Epoch 427 MSE 0.023206 on test set with deviation of 1.1e+01%
# Epoch -428 calculated in  3.58 s
# Epoch 428 MSE 0.022871 on test set with deviation of 2.5e+01%
# Epoch -429 calculated in  3.55 s
# Epoch 429 MSE 0.022544 on test set with deviation of 2.9e+01%
# Epoch -430 calculated in  3.56 s
# Epoch 430 MSE 0.022286 on test set with deviation of 3e+01%
# Epoch -431 calculated in  3.55 s
# Epoch 431 MSE 0.022065 on test set with deviation of 3.2e+01%
# Epoch -432 calculated in  3.57 s
# Epoch 432 MSE 0.021776 on test set with deviation of 3.2e+01%
# Epoch -433 calculated in  3.57 s
# Epoch 433 MSE 0.021499 on test set with deviation of 3.3e+01%
# Epoch -434 calculated in  3.55 s
# Epoch 434 MSE 0.021318 on test set with deviation of 3.4e+01%
# Epoch -435 calculated in  3.52 s
# Epoch 435 MSE 0.021204 on test set with deviation of 3.6e+01%
# Epoch -436 calculated in  3.55 s
# Epoch 436 MSE 0.021154 on test set with deviation of 3.7e+01%
# Epoch -437 calculated in  3.59 s
# Epoch 437 MSE 0.021107 on test set with deviation of 3.8e+01%
# Epoch -438 calculated in  3.58 s
# Epoch 438 MSE 0.021131 on test set with deviation of 3.9e+01%
# Epoch -439 calculated in  3.53 s
# Epoch 439 MSE 0.02112 on test set with deviation of 3.9e+01%
# Epoch -440 calculated in  3.60 s
# Epoch 440 MSE 0.021156 on test set with deviation of 4e+01%
# Epoch -441 calculated in  3.56 s
# Epoch 441 MSE 0.021228 on test set with deviation of 3.9e+01%
# Epoch -442 calculated in  3.54 s
# Epoch 442 MSE 0.026365 on test set with deviation of 5.3e+01%
# Epoch -443 calculated in  3.54 s
# Epoch 443 MSE 0.023989 on test set with deviation of 3.8e+01%
# Epoch -444 calculated in  3.56 s
# Epoch 444 MSE 0.021392 on test set with deviation of 3e+01%
# Epoch -445 calculated in  3.51 s
# Epoch 445 MSE 0.021048 on test set with deviation of 3.7e+01%
# Epoch -446 calculated in  3.58 s
# Epoch 446 MSE 0.020933 on test set with deviation of 3.9e+01%
# Epoch -447 calculated in  3.55 s
# Epoch 447 MSE 0.020954 on test set with deviation of 4e+01%
# Epoch -448 calculated in  3.54 s
# Epoch 448 MSE 0.02097 on test set with deviation of 4e+01%
# Epoch -449 calculated in  3.57 s
# Epoch 449 MSE 0.020979 on test set with deviation of 4e+01%
# Epoch -450 calculated in  3.57 s
# Epoch 450 MSE 0.020982 on test set with deviation of 4e+01%
# Epoch -451 calculated in  3.55 s
# Epoch 451 MSE 0.021137 on test set with deviation of 4e+01%
# Epoch -452 calculated in  3.55 s
# Epoch 452 MSE 0.021126 on test set with deviation of 4e+01%
# Epoch -453 calculated in  3.58 s
# Epoch 453 MSE 0.021778 on test set with deviation of 4.1e+01%
# Epoch -454 calculated in  3.53 s
# Epoch 454 MSE 0.021373 on test set with deviation of 3.6e+01%
# Epoch -455 calculated in  3.54 s
# Epoch 455 MSE 0.021527 on test set with deviation of 3.8e+01%
# Epoch -456 calculated in  3.53 s
# Epoch 456 MSE 0.021623 on test set with deviation of 3.7e+01%
# Epoch -457 calculated in  3.55 s
# Epoch 457 MSE 0.021988 on test set with deviation of 2.7e+01%
# Epoch -458 calculated in  3.53 s
# Epoch 458 MSE 0.02156 on test set with deviation of 3.1e+01%
# Epoch -459 calculated in  3.55 s
# Epoch 459 MSE 0.021213 on test set with deviation of 3.5e+01%
# Epoch -460 calculated in  3.61 s
# Epoch 460 MSE 0.021326 on test set with deviation of 3.5e+01%
# Epoch -461 calculated in  3.58 s
# Epoch 461 MSE 0.02156 on test set with deviation of 3.8e+01%
# Epoch -462 calculated in  3.56 s
# Epoch 462 MSE 0.021378 on test set with deviation of 3.8e+01%
# Epoch -463 calculated in  3.57 s
# Epoch 463 MSE 0.021172 on test set with deviation of 3.9e+01%
# Epoch -464 calculated in  3.56 s
# Epoch 464 MSE 0.02108 on test set with deviation of 4e+01%
# Epoch -465 calculated in  3.57 s
# Epoch 465 MSE 0.021015 on test set with deviation of 4.1e+01%
# Epoch -466 calculated in  3.52 s
# Epoch 466 MSE 0.020986 on test set with deviation of 4.2e+01%
# Epoch -467 calculated in  3.54 s
# Epoch 467 MSE 0.021 on test set with deviation of 4.2e+01%
# Epoch -468 calculated in  3.55 s
# Epoch 468 MSE 0.021016 on test set with deviation of 4.2e+01%
# Epoch -469 calculated in  3.55 s
# Epoch 469 MSE 0.021001 on test set with deviation of 4.2e+01%
# Epoch -470 calculated in  3.56 s
# Epoch 470 MSE 0.021197 on test set with deviation of 4.2e+01%
# Epoch -471 calculated in  3.56 s
# Epoch 471 MSE 0.022248 on test set with deviation of 4.2e+01%
# Epoch -472 calculated in  3.57 s
# Epoch 472 MSE 0.021078 on test set with deviation of 3.1e+01%
# Epoch -473 calculated in  3.57 s
# Epoch 473 MSE 0.02129 on test set with deviation of 3.6e+01%
# Epoch -474 calculated in  3.55 s
# Epoch 474 MSE 0.021206 on test set with deviation of 3.5e+01%
# Epoch -475 calculated in  3.55 s
# Epoch 475 MSE 0.021879 on test set with deviation of 3.7e+01%
# Epoch -476 calculated in  3.56 s
# Epoch 476 MSE 0.021354 on test set with deviation of 3.4e+01%
# Epoch -477 calculated in  3.55 s
# Epoch 477 MSE 0.021274 on test set with deviation of 3.5e+01%
# Epoch -478 calculated in  3.56 s
# Epoch 478 MSE 0.021166 on test set with deviation of 3.3e+01%
# Epoch -479 calculated in  3.57 s
# Epoch 479 MSE 0.021701 on test set with deviation of 3.5e+01%
# Epoch -480 calculated in  3.62 s
# Epoch 480 MSE 0.022504 on test set with deviation of 3.8e+01%
# Epoch -481 calculated in  3.56 s
# Epoch 481 MSE 0.02189 on test set with deviation of 3.2e+01%
# Epoch -482 calculated in  3.55 s
# Epoch 482 MSE 0.021697 on test set with deviation of 3.4e+01%
# Epoch -483 calculated in  3.52 s
# Epoch 483 MSE 0.021867 on test set with deviation of 3.6e+01%
# Epoch -484 calculated in  3.57 s
# Epoch 484 MSE 0.022136 on test set with deviation of 3.7e+01%
# Epoch -485 calculated in  3.55 s
# Epoch 485 MSE 0.022143 on test set with deviation of 3.8e+01%
# Epoch -486 calculated in  3.54 s
# Epoch 486 MSE 0.021896 on test set with deviation of 3.5e+01%
# Epoch -487 calculated in  3.57 s
# Epoch 487 MSE 0.021785 on test set with deviation of 3.3e+01%
# Epoch -488 calculated in  3.58 s
# Epoch 488 MSE 0.0223 on test set with deviation of 3.3e+01%
# Epoch -489 calculated in  3.55 s
# Epoch 489 MSE 0.022233 on test set with deviation of 2.8e+01%
# Epoch -490 calculated in  3.54 s
# Epoch 490 MSE 0.022893 on test set with deviation of 3e+01%
# Epoch -491 calculated in  3.56 s
# Epoch 491 MSE 0.022817 on test set with deviation of 3e+01%
# Epoch -492 calculated in  3.52 s
# Epoch 492 MSE 0.022505 on test set with deviation of 3.3e+01%
# Epoch -493 calculated in  3.55 s
# Epoch 493 MSE 0.022243 on test set with deviation of 3.5e+01%
# Epoch -494 calculated in  3.56 s
# Epoch 494 MSE 0.021943 on test set with deviation of 3.7e+01%
# Epoch -495 calculated in  3.55 s
# Epoch 495 MSE 0.021589 on test set with deviation of 3.8e+01%
# Epoch -496 calculated in  3.58 s
# Epoch 496 MSE 0.021247 on test set with deviation of 3.8e+01%
# Epoch -497 calculated in  3.54 s
# Epoch 497 MSE 0.020985 on test set with deviation of 3.9e+01%
# Epoch -498 calculated in  3.58 s
# Epoch 498 MSE 0.020836 on test set with deviation of 4e+01%
# Epoch -499 calculated in  3.57 s
# Epoch 499 MSE 0.02076 on test set with deviation of 4.1e+01%
# Epoch -500 calculated in  3.61 s
# ...
# Epoch -801 calculated in  3.54 s
# Epoch 801 MSE 0.019955 on test set with deviation of 5.4e+01%
# Epoch -802 calculated in  3.54 s
# Epoch 802 MSE 0.019964 on test set with deviation of 5.3e+01%
# Epoch -803 calculated in  3.52 s
# Epoch 803 MSE 0.020208 on test set with deviation of 5.2e+01%
# Epoch -804 calculated in  3.55 s
# Epoch 804 MSE 0.023197 on test set with deviation of 3.5e+01%
# Epoch -805 calculated in  3.58 s
# Epoch 805 MSE 0.020851 on test set with deviation of 2.6e+01%
# Epoch -806 calculated in  3.54 s
# Epoch 806 MSE 0.020871 on test set with deviation of 4.3e+01%
# Epoch -807 calculated in  3.56 s
# Epoch 807 MSE 0.021242 on test set with deviation of 4.9e+01%
# Epoch -808 calculated in  3.54 s
# Epoch 808 MSE 0.022248 on test set with deviation of 5.7e+01%
# Epoch -809 calculated in  3.54 s
# Epoch 809 MSE 0.021523 on test set with deviation of 5e+01%
# Epoch -810 calculated in  3.55 s
# Epoch 810 MSE 0.020589 on test set with deviation of 4.3e+01%
# Epoch -811 calculated in  3.53 s
# Epoch 811 MSE 0.020866 on test set with deviation of 4.4e+01%
# Epoch -812 calculated in  3.52 s
# Epoch 812 MSE 0.021271 on test set with deviation of 4.6e+01%
# Epoch -813 calculated in  3.56 s
# Epoch 813 MSE 0.021424 on test set with deviation of 4.4e+01%
# Epoch -814 calculated in  3.52 s
# Epoch 814 MSE 0.022338 on test set with deviation of 3.6e+01%
# Epoch -815 calculated in  3.53 s
# Epoch 815 MSE 0.021281 on test set with deviation of 2.7e+01%
# Epoch -816 calculated in  3.51 s
# Epoch 816 MSE 0.021462 on test set with deviation of 3.2e+01%
# Epoch -817 calculated in  3.51 s
# Epoch 817 MSE 0.021069 on test set with deviation of 3.5e+01%
# Epoch -818 calculated in  3.57 s
# Epoch 818 MSE 0.020877 on test set with deviation of 3.8e+01%
# Epoch -819 calculated in  3.54 s
# Epoch 819 MSE 0.020778 on test set with deviation of 4e+01%
# Epoch -820 calculated in  3.60 s
# Epoch 820 MSE 0.020676 on test set with deviation of 4.3e+01%
# Epoch -821 calculated in  3.56 s
# Epoch 821 MSE 0.020506 on test set with deviation of 4.4e+01%
# Epoch -822 calculated in  3.53 s
# Epoch 822 MSE 0.020325 on test set with deviation of 4.6e+01%
# Epoch -823 calculated in  3.55 s
# Epoch 823 MSE 0.02017 on test set with deviation of 4.9e+01%
# Epoch -824 calculated in  3.54 s
# Epoch 824 MSE 0.01999 on test set with deviation of 5e+01%
# Epoch -825 calculated in  3.53 s
# Epoch 825 MSE 0.019777 on test set with deviation of 5.1e+01%
# Epoch -826 calculated in  3.55 s
# Epoch 826 MSE 0.019687 on test set with deviation of 5.2e+01%
# Epoch -827 calculated in  3.55 s
# Epoch 827 MSE 0.019643 on test set with deviation of 5.3e+01%
# Epoch -828 calculated in  3.53 s
# Epoch 828 MSE 0.019593 on test set with deviation of 5.3e+01%
# Epoch -829 calculated in  3.55 s
# Epoch 829 MSE 0.01962 on test set with deviation of 5.4e+01%
# Epoch -830 calculated in  3.53 s
# Epoch 830 MSE 0.01962 on test set with deviation of 5.3e+01%
# Epoch -831 calculated in  3.53 s
# Epoch 831 MSE 0.0196 on test set with deviation of 5.3e+01%
# Epoch -832 calculated in  3.55 s
# Epoch 832 MSE 0.01961 on test set with deviation of 5.3e+01%
# Epoch -833 calculated in  3.52 s
# Epoch 833 MSE 0.019574 on test set with deviation of 5e+01%
# Epoch -834 calculated in  3.54 s
# Epoch 834 MSE 0.019934 on test set with deviation of 4.2e+01%
# Epoch -835 calculated in  3.55 s
# Epoch 835 MSE 0.01991 on test set with deviation of 4.3e+01%
# Epoch -836 calculated in  3.56 s
# Epoch 836 MSE 0.020627 on test set with deviation of 5.1e+01%
# Epoch -837 calculated in  3.52 s
# Epoch 837 MSE 0.020016 on test set with deviation of 4.4e+01%
# Epoch -838 calculated in  3.53 s
# Epoch 838 MSE 0.020149 on test set with deviation of 4.6e+01%
# Epoch -839 calculated in  3.55 s
# Epoch 839 MSE 0.019795 on test set with deviation of 4.8e+01%
# Epoch -840 calculated in  3.57 s
# Epoch 840 MSE 0.020059 on test set with deviation of 5.2e+01%
# Epoch -841 calculated in  3.53 s
# Epoch 841 MSE 0.019845 on test set with deviation of 5.1e+01%
# Epoch -842 calculated in  3.54 s
# Epoch 842 MSE 0.019736 on test set with deviation of 5.1e+01%
# Epoch -843 calculated in  3.61 s
# Epoch 843 MSE 0.01967 on test set with deviation of 5.3e+01%
# Epoch -844 calculated in  3.57 s
# Epoch 844 MSE 0.019677 on test set with deviation of 5.4e+01%
# Epoch -845 calculated in  3.56 s
# Epoch 845 MSE 0.01957 on test set with deviation of 5.3e+01%
# Epoch -846 calculated in  3.51 s
# Epoch 846 MSE 0.019723 on test set with deviation of 5.4e+01%
# Epoch -847 calculated in  3.55 s
# Epoch 847 MSE 0.019818 on test set with deviation of 5.2e+01%
# Epoch -848 calculated in  3.54 s
# Epoch 848 MSE 0.020268 on test set with deviation of 5.3e+01%
# Epoch -849 calculated in  3.53 s
# Epoch 849 MSE 0.02125 on test set with deviation of 2e+01%
# Epoch -850 calculated in  3.56 s
# Epoch 850 MSE 0.02031 on test set with deviation of 4.2e+01%
# Epoch -851 calculated in  3.53 s
# Epoch 851 MSE 0.019981 on test set with deviation of 4.6e+01%
# Epoch -852 calculated in  3.54 s
# Epoch 852 MSE 0.020318 on test set with deviation of 4.5e+01%
# Epoch -853 calculated in  3.55 s
# Epoch 853 MSE 0.02157 on test set with deviation of 4.9e+01%
# Epoch -854 calculated in  3.54 s
# Epoch 854 MSE 0.021017 on test set with deviation of 4.7e+01%
# Epoch -855 calculated in  3.56 s
# Epoch 855 MSE 0.02117 on test set with deviation of 5.1e+01%
# Epoch -856 calculated in  3.59 s
# Epoch 856 MSE 0.020649 on test set with deviation of 4.9e+01%
# Epoch -857 calculated in  3.60 s
# Epoch 857 MSE 0.020303 on test set with deviation of 4.7e+01%
# Epoch -858 calculated in  3.73 s
# Epoch 858 MSE 0.020282 on test set with deviation of 4.8e+01%
# Epoch -859 calculated in  3.56 s
# Epoch 859 MSE 0.020365 on test set with deviation of 4.9e+01%
# Epoch -860 calculated in  3.57 s
# Epoch 860 MSE 0.020458 on test set with deviation of 5.1e+01%
# Epoch -861 calculated in  3.56 s
# Epoch 861 MSE 0.020524 on test set with deviation of 5.3e+01%
# Epoch -862 calculated in  3.57 s
# Epoch 862 MSE 0.020503 on test set with deviation of 5.4e+01%
# Epoch -863 calculated in  3.54 s
# Epoch 863 MSE 0.02038 on test set with deviation of 5.5e+01%
# Epoch -864 calculated in  3.57 s
# Epoch 864 MSE 0.02027 on test set with deviation of 5.6e+01%
# Epoch -865 calculated in  3.58 s
# Epoch 865 MSE 0.020092 on test set with deviation of 5.6e+01%
# Epoch -866 calculated in  3.75 s
# Epoch 866 MSE 0.019908 on test set with deviation of 5.6e+01%
# Epoch -867 calculated in  3.76 s
# Epoch 867 MSE 0.019801 on test set with deviation of 5.5e+01%
# Epoch -868 calculated in  3.69 s
# Epoch 868 MSE 0.0197 on test set with deviation of 5.5e+01%
# Epoch -869 calculated in  3.67 s
# Epoch 869 MSE 0.01971 on test set with deviation of 5.5e+01%
# Epoch -870 calculated in  3.58 s
# Epoch 870 MSE 0.019854 on test set with deviation of 5.5e+01%
# Epoch -871 calculated in  3.53 s
# Epoch 871 MSE 0.01981 on test set with deviation of 5.2e+01%
# Epoch -872 calculated in  3.55 s
# Epoch 872 MSE 0.023838 on test set with deviation of 4.8e+01%
# Epoch -873 calculated in  3.57 s
# Epoch 873 MSE 0.020399 on test set with deviation of 3e+01%
# Epoch -874 calculated in  3.56 s
# Epoch 874 MSE 0.020169 on test set with deviation of 4.7e+01%
# Epoch -875 calculated in  3.60 s
# Epoch 875 MSE 0.019896 on test set with deviation of 4.9e+01%
# Epoch -876 calculated in  3.61 s
# Epoch 876 MSE 0.019846 on test set with deviation of 5.1e+01%
# Epoch -877 calculated in  3.53 s
# Epoch 877 MSE 0.019796 on test set with deviation of 5.2e+01%
# Epoch -878 calculated in  3.53 s
# Epoch 878 MSE 0.019713 on test set with deviation of 5.4e+01%
# Epoch -879 calculated in  3.57 s
# Epoch 879 MSE 0.019658 on test set with deviation of 5.5e+01%
# Epoch -880 calculated in  3.63 s
# Epoch 880 MSE 0.019607 on test set with deviation of 5.5e+01%
# Epoch -881 calculated in  3.55 s
# Epoch 881 MSE 0.019596 on test set with deviation of 5.6e+01%
# Epoch -882 calculated in  3.54 s
# Epoch 882 MSE 0.019641 on test set with deviation of 5.6e+01%
# Epoch -883 calculated in  3.63 s
# Epoch 883 MSE 0.019837 on test set with deviation of 5.6e+01%
# Epoch -884 calculated in  3.67 s
# Epoch 884 MSE 0.019749 on test set with deviation of 5.2e+01%
# Epoch -885 calculated in  3.63 s
# Epoch 885 MSE 0.019837 on test set with deviation of 5.1e+01%
# Epoch -886 calculated in  3.61 s
# Epoch 886 MSE 0.02035 on test set with deviation of 5e+01%
# Epoch -887 calculated in  3.55 s
# Epoch 887 MSE 0.020895 on test set with deviation of 4.6e+01%
# Epoch -888 calculated in  3.57 s
# Epoch 888 MSE 0.020053 on test set with deviation of 4.2e+01%
# Epoch -889 calculated in  3.56 s
# Epoch 889 MSE 0.020133 on test set with deviation of 4.8e+01%
# Epoch -890 calculated in  3.55 s
# Epoch 890 MSE 0.020244 on test set with deviation of 5e+01%
# Epoch -891 calculated in  3.57 s
# Epoch 891 MSE 0.020409 on test set with deviation of 4.7e+01%
# Epoch -892 calculated in  3.56 s
# Epoch 892 MSE 0.020826 on test set with deviation of 5e+01%
# Epoch -893 calculated in  3.55 s
# Epoch 893 MSE 0.021535 on test set with deviation of 5.8e+01%
# Epoch -894 calculated in  3.53 s
# Epoch 894 MSE 0.021487 on test set with deviation of 5.3e+01%
# Epoch -895 calculated in  3.53 s
# Epoch 895 MSE 0.020887 on test set with deviation of 4.4e+01%
# Epoch -896 calculated in  3.55 s
# Epoch 896 MSE 0.025202 on test set with deviation of 3.4e+01%
# Epoch -897 calculated in  3.55 s
# Epoch 897 MSE 0.021279 on test set with deviation of 3.1e+01%
# Epoch -898 calculated in  3.56 s
# Epoch 898 MSE 0.020872 on test set with deviation of 3.2e+01%
# Epoch -899 calculated in  3.55 s
# Epoch 899 MSE 0.020785 on test set with deviation of 3.7e+01%
# Epoch -900 calculated in  3.62 s
# Epoch 900 MSE 0.020602 on test set with deviation of 3.9e+01%
# Epoch -901 calculated in  3.56 s
# Epoch 901 MSE 0.02049 on test set with deviation of 4.2e+01%
# Epoch -902 calculated in  3.52 s
# Epoch 902 MSE 0.020411 on test set with deviation of 4.4e+01%
# Epoch -903 calculated in  3.55 s
# Epoch 903 MSE 0.020297 on test set with deviation of 4.6e+01%
# Epoch -904 calculated in  3.55 s
# Epoch 904 MSE 0.020157 on test set with deviation of 4.8e+01%
# Epoch -905 calculated in  3.55 s
# Epoch 905 MSE 0.020046 on test set with deviation of 5e+01%
# Epoch -906 calculated in  3.54 s
# Epoch 906 MSE 0.019919 on test set with deviation of 5.2e+01%
# Epoch -907 calculated in  3.54 s
# Epoch 907 MSE 0.019679 on test set with deviation of 5.3e+01%
# Epoch -908 calculated in  3.54 s
# Epoch 908 MSE 0.019566 on test set with deviation of 5.4e+01%
# Epoch -909 calculated in  3.55 s
# Epoch 909 MSE 0.019525 on test set with deviation of 5.5e+01%
# Epoch -910 calculated in  3.58 s
# Epoch 910 MSE 0.019447 on test set with deviation of 5.5e+01%
# Epoch -911 calculated in  3.53 s
# Epoch 911 MSE 0.019425 on test set with deviation of 5.5e+01%
# Epoch -912 calculated in  3.56 s
# Epoch 912 MSE 0.019397 on test set with deviation of 5.5e+01%
# Epoch -913 calculated in  3.60 s
# Epoch 913 MSE 0.019414 on test set with deviation of 5.5e+01%
# Epoch -914 calculated in  3.57 s
# Epoch 914 MSE 0.019471 on test set with deviation of 5.5e+01%
# Epoch -915 calculated in  3.63 s
# Epoch 915 MSE 0.019608 on test set with deviation of 5.6e+01%
# Epoch -916 calculated in  3.55 s
# Epoch 916 MSE 0.019659 on test set with deviation of 5.1e+01%
# Epoch -917 calculated in  3.55 s
# Epoch 917 MSE 0.019654 on test set with deviation of 5.1e+01%
# Epoch -918 calculated in  3.55 s
# Epoch 918 MSE 0.020901 on test set with deviation of 4.3e+01%
# Epoch -919 calculated in  3.66 s
# Epoch 919 MSE 0.020662 on test set with deviation of 1.7e+01%
# Epoch -920 calculated in  3.61 s
# Epoch 920 MSE 0.01991 on test set with deviation of 4.2e+01%
# Epoch -921 calculated in  3.56 s
# Epoch 921 MSE 0.019753 on test set with deviation of 4.7e+01%
# Epoch -922 calculated in  3.54 s
# Epoch 922 MSE 0.019658 on test set with deviation of 4.9e+01%
# Epoch -923 calculated in  3.67 s
# Epoch 923 MSE 0.019566 on test set with deviation of 5.1e+01%
# Epoch -924 calculated in  3.64 s
# Epoch 924 MSE 0.019471 on test set with deviation of 5.3e+01%
# Epoch -925 calculated in  3.65 s
# Epoch 925 MSE 0.0194 on test set with deviation of 5.5e+01%
# Epoch -926 calculated in  3.58 s
# Epoch 926 MSE 0.019354 on test set with deviation of 5.5e+01%
# Epoch -927 calculated in  3.56 s
# Epoch 927 MSE 0.019336 on test set with deviation of 5.5e+01%
# Epoch -928 calculated in  3.55 s
# Epoch 928 MSE 0.01936 on test set with deviation of 5.6e+01%
# Epoch -929 calculated in  3.54 s
# Epoch 929 MSE 0.019465 on test set with deviation of 5.6e+01%
# Epoch -930 calculated in  3.54 s
# Epoch 930 MSE 0.019628 on test set with deviation of 5.4e+01%
# Epoch -931 calculated in  3.58 s
# Epoch 931 MSE 0.019722 on test set with deviation of 5.4e+01%
# Epoch -932 calculated in  3.65 s
# Epoch 932 MSE 0.019961 on test set with deviation of 5.3e+01%
# Epoch -933 calculated in  3.57 s
# Epoch 933 MSE 0.019845 on test set with deviation of 5e+01%
# Epoch -934 calculated in  3.56 s
# Epoch 934 MSE 0.020124 on test set with deviation of 4.8e+01%
# Epoch -935 calculated in  3.52 s
# Epoch 935 MSE 0.02009 on test set with deviation of 4.5e+01%
# Epoch -936 calculated in  3.66 s
# Epoch 936 MSE 0.019965 on test set with deviation of 4.6e+01%
# Epoch -937 calculated in  3.58 s
# Epoch 937 MSE 0.020173 on test set with deviation of 4.6e+01%
# Epoch -938 calculated in  3.59 s
# Epoch 938 MSE 0.021353 on test set with deviation of 3.4e+01%
# Epoch -939 calculated in  3.58 s
# Epoch 939 MSE 0.021226 on test set with deviation of 4.9e+01%
# Epoch -940 calculated in  3.65 s
# Epoch 940 MSE 0.02088 on test set with deviation of 5.3e+01%
# Epoch -941 calculated in  3.57 s
# Epoch 941 MSE 0.020366 on test set with deviation of 4.9e+01%
# Epoch -942 calculated in  3.55 s
# Epoch 942 MSE 0.02016 on test set with deviation of 4.8e+01%
# Epoch -943 calculated in  3.54 s
# Epoch 943 MSE 0.020209 on test set with deviation of 4.9e+01%
# Epoch -944 calculated in  3.55 s
# Epoch 944 MSE 0.020347 on test set with deviation of 5.1e+01%
# Epoch -945 calculated in  3.59 s
# Epoch 945 MSE 0.020407 on test set with deviation of 5.3e+01%
# Epoch -946 calculated in  3.54 s
# Epoch 946 MSE 0.020372 on test set with deviation of 5.5e+01%
# Epoch -947 calculated in  3.56 s
# Epoch 947 MSE 0.020182 on test set with deviation of 5.5e+01%
# Epoch -948 calculated in  3.54 s
# Epoch 948 MSE 0.020015 on test set with deviation of 5.6e+01%
# Epoch -949 calculated in  3.56 s
# Epoch 949 MSE 0.019883 on test set with deviation of 5.7e+01%
# Epoch -950 calculated in  3.56 s
# Epoch 950 MSE 0.01974 on test set with deviation of 5.7e+01%
# Epoch -951 calculated in  3.53 s
# Epoch 951 MSE 0.019628 on test set with deviation of 5.7e+01%
# Epoch -952 calculated in  3.57 s
# Epoch 952 MSE 0.019568 on test set with deviation of 5.7e+01%
# Epoch -953 calculated in  3.67 s
# Epoch 953 MSE 0.019501 on test set with deviation of 5.7e+01%
# Epoch -954 calculated in  3.66 s
# Epoch 954 MSE 0.019531 on test set with deviation of 5.7e+01%
# Epoch -955 calculated in  3.62 s
# Epoch 955 MSE 0.019581 on test set with deviation of 5.7e+01%
# Epoch -956 calculated in  3.79 s
# Epoch 956 MSE 0.019539 on test set with deviation of 5.5e+01%
# Epoch -957 calculated in  3.64 s
# Epoch 957 MSE 0.019669 on test set with deviation of 5.5e+01%
# Epoch -958 calculated in  3.60 s
# Epoch 958 MSE 0.020845 on test set with deviation of 4.5e+01%
# Epoch -959 calculated in  3.54 s
# Epoch 959 MSE 0.020967 on test set with deviation of 3.5e+01%
# Epoch -960 calculated in  3.64 s
# Epoch 960 MSE 0.020121 on test set with deviation of 4.3e+01%
# Epoch -961 calculated in  3.56 s
# Epoch 961 MSE 0.020062 on test set with deviation of 4.9e+01%
# Epoch -962 calculated in  3.59 s
# Epoch 962 MSE 0.019768 on test set with deviation of 5.1e+01%
# Epoch -963 calculated in  3.56 s
# Epoch 963 MSE 0.019633 on test set with deviation of 5.1e+01%
# Epoch -964 calculated in  3.56 s
# Epoch 964 MSE 0.019566 on test set with deviation of 5.2e+01%
# Training duration 01:01:00:01
# Number of training variable 126941
# INFO:tensorflow:Restoring parameters from Experiments/2017-12-20-16-31/temp/myFinalModel.ckpt
# INFO:tensorflow:Froze 8 variables.
# Converted 8 variables to const ops.
# done, good job kids

# %%
from show import *
# %matplotlib notebook
showPickle(nameFigEstimation)
# Out:
# <img src="data:image/png;base64,..." width="529">
